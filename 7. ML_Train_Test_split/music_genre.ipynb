# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('music_genre_dataset.csv')
print(df.head())

x = df[['duration_seconds', 'tempo_bpm', 'energy_level', 'genre_label']]
y = df['genre_label']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=42
)

x_test, x_val, y_test, y_val = train_test_split(
    x_test, y_test, test_size=0.5, random_state=42
)

# print dataset sizes
print(f"Training set: {len(x_train)} samples")
print(f"Validation set: {len(x_val)} samples")
print(f"Test set: {len(x_test)} samples")
# Out:
#    audio_id  duration_seconds  tempo_bpm  energy_level  genre_label
# 0         1               222        154          0.35            1
# 1         2               299        107          0.50            1
# 2         3               212         74          0.41            1
# 3         4               134        131          0.95            1
# 4         5               226        137          0.87            1
# Training set: 70 samples
# Validation set: 15 samples
# Test set: 15 samples
