# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np

# %%
# Toy spam dataset
# Features: [word_count, has_link, caps_ratio]
X = np.array([
    [50, 1, 0.8], # SPAM
    [200, 0, 0.1], # !SPAM
    [30, 1, 0.9], # SPAM
    [180, 0, 0.05], #!SPAM
    [10, 1, 0.95], # SPAM
    [220, 0, 0.08] # !SPAM
])
y = np.array([1, 0, 1, 0, 1, 0])

# %%
# split data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train model
model = LogisticRegression()
model.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)
print("Actual vs Prediction")
for actual, pred in zip(y_test, y_pred):
    print(f"Actual: {actual}, Prediction: {pred}")

# %%
# Accuracy
proba = model.predict_proba(x_test)[:, 1]
print(proba)
print("Probabilities: ", proba.round(2))
print(f"Accuracy: {accuracy_score(y_test, y_pred)*100}%")

# %%
# Try a new email
new_email = np.array([[15, 1, 0.88]])
print(f"New email is: {model.predict(new_email)[0]}")
