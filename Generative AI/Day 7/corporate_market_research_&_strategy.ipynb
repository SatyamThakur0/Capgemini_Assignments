# %%
# Scenario: Corporate Market Research & Strategy
# A company wants to explore launching a new product in a competitive market. The Manager Agent oversees the process and delegates tasks to specialized workers.

# 👩‍💼 Manager Agent
# - Receives the overall goal: “Evaluate feasibility of launching Product Y in Asia.”
# - Dynamically assigns tasks to worker agents depending on what’s needed.
# - Example: If budget is unclear → send to Finance Worker. If regulations are complex → send to Legal Worker.

# ================================
# 📊 Worker Agents
# ================================
# - Market Research Worker
# - Collects competitor data, customer preferences, and demand forecasts.
# - Reports: “High demand in Tier‑1 cities, moderate competition.”
# - Finance Worker
# - Analyzes budget, ROI, and pricing strategy.
# - Reports: “Estimated $10M investment, ROI in 2 years.”
# - Operations Worker
# - Evaluates supply chain, production capacity, and logistics.
# - Reports: “Factories can scale up, but shipping costs are high.”
# - Legal Worker
# - Reviews compliance, intellectual property, and regional regulations.
# - Reports: “Trademark available, but import laws require certification.”
# - HR Worker
# - Assesses staffing needs and training requirements.
# - Reports: “Need 50 new hires for customer support and sales.”

# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("NVIDIA_API_KEY")

def call_llm(prompt):
    url = "https://integrate.api.nvidia.com/v1/chat/completions"

    headers = {
        "Authorization": f"Bearer {API_KEY}",
        "Content-Type": "application/json"
    }

    data = {
        "model": "meta/llama3-70b-instruct",
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.3
    }

    res = requests.post(url, headers=headers, json=data)
    return res.json()["choices"][0]["message"]["content"]

# %%
def market_research_worker(goal):
    prompt = f"""
    You are a Market Research Expert.

    Goal: {goal}

    Analyze:
    - Demand
    - Competition
    - Customer preferences

    Give short insights.
    """
    return call_llm(prompt)


def finance_worker(goal):
    prompt = f"""
    You are a Finance Expert.

    Goal: {goal}

    Analyze:
    - Budget required
    - ROI
    - Pricing strategy

    Give short insights.
    """
    return call_llm(prompt)


def operations_worker(goal):
    prompt = f"""
    You are an Operations Expert.

    Goal: {goal}

    Analyze:
    - Supply chain
    - Production capacity
    - Logistics

    Give short insights.
    """
    return call_llm(prompt)


def legal_worker(goal):
    prompt = f"""
    You are a Legal Expert.

    Goal: {goal}

    Analyze:
    - Regulations
    - Compliance
    - IP issues

    Give short insights.
    """
    return call_llm(prompt)


def hr_worker(goal):
    prompt = f"""
    You are an HR Expert.

    Goal: {goal}

    Analyze:
    - Hiring needs
    - Training
    - Workforce planning

    Give short insights.
    """
    return call_llm(prompt)

# %%
def manager_agent(goal):
    print("Manager: Analyzing goal...")

    # Step 1: Decide which workers to call
    decision_prompt = f"""
    You are a Manager Agent.

    Goal: {goal}

    Decide which workers are needed from:
    [market, finance, operations, legal, hr]

    Return ONLY a Python list.
    Example: ["market", "finance"]
    """

    decision = call_llm(decision_prompt)

    print("Manager decided:", decision)

    results = {}

    # Step 2: Call workers dynamically
    if "market" in decision:
        results["market"] = market_research_worker(goal)

    if "finance" in decision:
        results["finance"] = finance_worker(goal)

    if "operations" in decision:
        results["operations"] = operations_worker(goal)

    if "legal" in decision:
        results["legal"] = legal_worker(goal)

    if "hr" in decision:
        results["hr"] = hr_worker(goal)

    # Step 3: Final decision
    final_prompt = f"""
    You are a Strategy Head.

    Goal: {goal}

    Worker Reports:
    {results}

    Give final decision:
    - Should we launch?
    - Key risks
    - Strategy
    """

    final_output = call_llm(final_prompt)

    return final_output

# %%
goal = "Evaluate feasibility of launching Product Y in Asia"

result = manager_agent(goal)

print("\nFINAL STRATEGY:\n")
print(result)
# Out:
# Manager: Analyzing goal...
# Manager decided: ["market", "finance", "operations", "legal"]
#
# FINAL STRATEGY:
#
# **Final Decision:**
#
# Based on the reports from the Market Research, Finance, Operations, and Legal experts, I recommend that we **launch Product Y in Asia**. The analysis suggests that there is a growing demand for innovative products in the region, and Product Y's unique features and benefits align well with Asian consumers' preferences and values.
#
# **Key Risks:**
#
# 1. **Competition**: The Asian market is highly competitive, with established brands and local players vying for market share.
# 2. **Regulatory Compliance**: Navigating complex regulatory frameworks, language barriers, and cultural differences in each country can be challenging.
# 3. **Supply Chain Risks**: Selecting and vetting reliable suppliers, and investing in supplier development programs, may be necessary to ensure quality and reliability.
# 4. **IP Protection**: Patent protection and trademark registration are crucial to prevent counterfeiting and IP infringement in Asia.
#
# **Strategy:**
#
# To mitigate these risks and ensure a successful market entry, I recommend the following strategy:
#
# 1. **Conduct thorough market research** to better understand local market conditions, competitor pricing, and customer preferences.
# 2. **Develop a tailored marketing strategy** that takes into account the unique needs and preferences of Asian consumers, including online shopping habits and social media influence.
# 3. **Establish a strong supply chain** by selecting reliable suppliers, investing in supplier development programs, and implementing quality control measures.
# 4. **Invest in regulatory compliance** by registering products with relevant authorities, complying with Good Manufacturing Practices (GMP) and Good Distribution Practices (GDP), and meeting labeling and packaging requirements.
# 5. **Protect IP rights** by filing patent applications in key Asian markets, registering trademarks, and implementing anti-counterfeiting measures.
# 6. **Monitor and adapt** to changing market trends, customer feedback, and financial performance to adjust our strategy as needed.
#
# By following this strategy, we can minimize risks and maximize the potential for success in the Asian market.
